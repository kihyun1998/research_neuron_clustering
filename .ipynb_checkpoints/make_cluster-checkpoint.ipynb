# %%
"""
클러스터링 구간 나누고 저장
"""

from neuron import h
import json

h.load_file("pyrCell.hoc")
myCell = h.pyrCell()


#open json file
file_path = "./distance.json"
with open(file_path, 'r') as json_file:
    json_data = json.load(json_file)



#===========
#거리별 자르기


start_8=[]; start_9=[]
for i,dic in json_data.items():
    for j in dic:
        if j[15:17]=="0)" and dic[j] // 100 == 8:
            text = i.replace("apic","")
            text = text.replace("[","")
            text = text.replace("]","")
            start_8.append(text)
        elif j[15:17]=="0)" and dic[j] // 100 == 9:
            text = i.replace("apic","")
            text = text.replace("[","")
            text = text.replace("]","")
            start_9.append(text)

#===========

        
start_8 = list(map(int,start_8))
start_9 = list(map(int,start_9))


clusters =[]
clusters.append(start_8)
clusters.append(start_9)



file_path2 = "./cluster2.json"
total2={}
for i,v in enumerate(clusters):
    total2[f'start_{i+8}'] = v

    with open(file_path2, 'w') as outfile:
        json.dump(total2, outfile, indent=4)

# %%
new_cluster = []

# %%
import json
with open(file_path, 'r') as json_file:
    json_data = json.load(json_file)
    
for i in start_8:
    if json_data[f"apic[{i}]"][f'myCell.apic[{i}(0.99)]'] > 1000:
        print(f"apic[{i}][myCell.apic[{i}(0)]] : ",json_data[f"apic[{i}]"][f'myCell.apic[{i}(0)]'])
        print(f"apic[{i}][myCell.apic[{i}(0.99)]] : ",json_data[f"apic[{i}]"][f'myCell.apic[{i}(0.99)]'],"\n\n")
        new_cluster.append(i)
# Out:
# apic[16][myCell.apic[16(0)]] :  879.9892628657612
# apic[16][myCell.apic[16(0.99)]] :  1074.9668619082315
#
#
# apic[46][myCell.apic[46(0)]] :  880.1758056201497
# apic[46][myCell.apic[46(0.99)]] :  1065.3774272675403
#
#
# apic[71][myCell.apic[71(0)]] :  868.8331609353734
# apic[71][myCell.apic[71(0.99)]] :  1099.0019593089535

# %%
import json
with open(file_path, 'r') as json_file:
    json_data = json.load(json_file)
    
for i in start_9:
    if json_data[f"apic[{i}]"][f'myCell.apic[{i}(0.99)]'] > 1000:
        print(f"apic[{i}][myCell.apic[{i}(0)]] : ",json_data[f"apic[{i}]"][f'myCell.apic[{i}(0)]'])
        print(f"apic[{i}][myCell.apic[{i}(0.99)]] : ",json_data[f"apic[{i}]"][f'myCell.apic[{i}(0.99)]'],"\n\n")
        new_cluster.append(i)
# Out:
# apic[20][myCell.apic[20(0)]] :  927.6537826268351
# apic[20][myCell.apic[20(0.99)]] :  1000.0410291781112
#
#
# apic[25][myCell.apic[25(0)]] :  927.6537826268351
# apic[25][myCell.apic[25(0.99)]] :  1086.1981385567303
#
#
# apic[27][myCell.apic[27(0)]] :  947.2070829783792
# apic[27][myCell.apic[27(0.99)]] :  1101.517152664239
#
#
# apic[31][myCell.apic[31(0)]] :  940.1419189599986
# apic[31][myCell.apic[31(0.99)]] :  1076.7069369839896
#
#
# apic[33][myCell.apic[33(0)]] :  911.3620271198607
# apic[33][myCell.apic[33(0.99)]] :  1006.5892122560414
#
#
# apic[36][myCell.apic[36(0)]] :  911.3620271198607
# apic[36][myCell.apic[36(0.99)]] :  1078.2544646964798
#
#
# apic[50][myCell.apic[50(0)]] :  900.3897233914015
# apic[50][myCell.apic[50(0.99)]] :  1034.7083927933993
#
#
# apic[56][myCell.apic[56(0)]] :  993.6479204092418
# apic[56][myCell.apic[56(0.99)]] :  1117.2203908317265
#
#
# apic[57][myCell.apic[57(0)]] :  993.6479204092418
# apic[57][myCell.apic[57(0.99)]] :  1126.1016202571352
#
#
# apic[60][myCell.apic[60(0)]] :  942.3492069796534
# apic[60][myCell.apic[60(0.99)]] :  1002.8213272528518
#
#
# apic[63][myCell.apic[63(0)]] :  942.3492069796534
# apic[63][myCell.apic[63(0.99)]] :  1017.2687586769289

# %%
new_cluster.sort()
new_cluster
# Out:
# [16, 20, 25, 27, 31, 33, 36, 46, 50, 56, 57, 60, 63, 71]

# %%
import json
with open(file_path, 'r') as json_file:
    json_data = json.load(json_file)
    
print(json_data['apic[11]']['myCell.apic[11(0)]'])


[f'myCell.apic[{i}(0.99)]']
# Out:
# 473.9901820677646

# %%
res_cluster={}
file_path3 = "./cluster3.json"
res_cluster["res"]=new_cluster
with open(file_path3, 'w') as outfile:
    json.dump(res_cluster, outfile, indent=4)

# %%
with open(file_path, 'r') as json_file:
    json_data = json.load(json_file)


for i in new_cluster:
    r=0
    for j in range(11):
        if json_data[f"apic[{i}]"][f'myCell.apic[{i}({r})]'] > 900:
            print(f"apic[{i}][myCell.apic[{i}({r})]] : ",json_data[f"apic[{i}]"][f'myCell.apic[{i}({r})]'])
        r+=0.09
        r=round(r,2)
    print('\n')
# Out:
# apic[16][myCell.apic[16(0.18)]] :  907.8432055861142
# apic[16][myCell.apic[16(0.27)]] :  926.412500733016
# apic[16][myCell.apic[16(0.36)]] :  944.981795879918
# apic[16][myCell.apic[16(0.45)]] :  963.5510910268199
# apic[16][myCell.apic[16(0.54)]] :  982.1203861737218
# apic[16][myCell.apic[16(0.63)]] :  1000.6896813206237
# apic[16][myCell.apic[16(0.72)]] :  1019.2589764675256
# apic[16][myCell.apic[16(0.81)]] :  1037.8282716144276
# apic[16][myCell.apic[16(0.9)]] :  1056.3975667613295
#
#
# apic[20][myCell.apic[20(0)]] :  927.6537826268351
# apic[20][myCell.apic[20(0.09)]] :  931.1007943673721
# apic[20][myCell.apic[20(0.18)]] :  937.994817848446
# apic[20][myCell.apic[20(0.27)]] :  944.8888413295199
# apic[20][myCell.apic[20(0.36)]] :  951.7828648105939
# apic[20][myCell.apic[20(0.45)]] :  958.6768882916678
# apic[20][myCell.apic[20(0.54)]] :  965.5709117727416
# apic[20][myCell.apic[20(0.63)]] :  972.4649352538156
# apic[20][myCell.apic[20(0.72)]] :  979.3589587348895
# apic[20][myCell.apic[20(0.81)]] :  986.2529822159634
# apic[20][myCell.apic[20(0.9)]] :  993.1470056970373
#
#
# apic[25][myCell.apic[25(0)]] :  927.6537826268351
# apic[25][myCell.apic[25(0.09)]] :  935.203513861592
# apic[25][myCell.apic[25(0.18)]] :  950.3029763311058
# apic[60][myCell.apic[60(0.27)]] :  956.7473308542245
# apic[60][myCell.apic[60(0.36)]] :  962.5065804040529
# apic[60][myCell.apic[60(0.45)]] :  968.2658299538814
# apic[60][myCell.apic[60(0.54)]] :  974.0250795037098
# apic[60][myCell.apic[60(0.63)]] :  979.7843290535382
# apic[60][myCell.apic[60(0.72)]] :  985.5435786033667
# apic[60][myCell.apic[60(0.81)]] :  991.302828153195
# apic[60][myCell.apic[60(0.9)]] :  997.0620777030234
#
#
# apic[63][myCell.apic[63(0)]] :  942.3492069796534
# apic[63][myCell.apic[63(0.09)]] :  945.9168046795237
# apic[63][myCell.apic[63(0.18)]] :  953.0520000792643
# apic[63][myCell.apic[63(0.27)]] :  960.1871954790048
# apic[63][myCell.apic[63(0.36)]] :  967.3223908787453
# apic[63][myCell.apic[63(0.45)]] :  974.4575862784858
# apic[63][myCell.apic[63(0.54)]] :  981.5927816782263
# apic[63][myCell.apic[63(0.63)]] :  988.7279770779668
# apic[63][myCell.apic[63(0.72)]] :  995.8631724777074
# apic[63][myCell.apic[63(0.81)]] :  1002.9983678774479
# apic[63][myCell.apic[63(0.9)]] :  1010.1335632771884
#
#
# apic[71][myCell.apic[71(0.18)]] :  901.7144178458849
# apic[71][myCell.apic[71(0.27)]] :  923.6352557862258
# apic[71][myCell.apic[71(0.36)]] :  945.5560937265668
# apic[71][myCell.apic[71(0.45)]] :  967.4769316669077
# apic[71][myCell.apic[71(0.54)]] :  989.3977696072486
# apic[71][myCell.apic[71(0.63)]] :  1011.3186075475896
# apic[71][myCell.apic[71(0.72)]] :  1033.2394454879307
# apic[71][myCell.apic[71(0.81)]] :  1055.1602834282714
# apic[71][myCell.apic[71(0.9)]] :  1077.0811213686127

# %%
from neuron import h
import json

h.load_file("pyrCell.hoc")
myCell = h.pyrCell()


#open json file
file_path = "./distance.json"
with open(file_path, 'r') as json_file:
    json_data = json.load(json_file)
file_path2 = "./cluster3.json"
with open(file_path2, 'r') as json_file2:
    json_data2 = json.load(json_file2)
new_cluster = json_data2['res']


test_cluster = {}

for i in new_cluster:
    r=0;cnt=0;idx=[]
    for j in range(11):
        if 930 < json_data[f"apic[{i}]"][f'myCell.apic[{i}({r})]'] < 1000:
            cnt+=1
#             print(f"apic[{i}][myCell.apic[{i}({r})]] : ",json_data[f"apic[{i}]"][f'myCell.apic[{i}({r})]'])
            idx.append([i,r])
        r+=0.09
        r=round(r,2)
    if cnt>=5:
        test_cluster[f'apic[{i}]'] = idx
#     print('\n')

file_path3 = "./test_cluster.json"
with open(file_path3, 'w') as outfile:
    json.dump(test_cluster, outfile, indent=4)

# %%
from neuron import h
import json

h.load_file("pyrCell.hoc")
myCell = h.pyrCell()


#open json file
file_path = "./distance.json"
with open(file_path, 'r') as json_file:
    json_data = json.load(json_file)
file_path2 = "./cluster3.json"
with open(file_path2, 'r') as json_file2:
    json_data2 = json.load(json_file2)
new_cluster = json_data2['res']


test_cluster = {}

for i in new_cluster:
    r=0;cnt=0;idx=[]
    for j in range(11):
        if 930 < json_data[f"apic[{i}]"][f'myCell.apic[{i}({r})]'] < 1000:
            cnt+=1
#             print(f"apic[{i}][myCell.apic[{i}({r})]] : ",json_data[f"apic[{i}]"][f'myCell.apic[{i}({r})]'])
            idx.append([i,r])
        r+=0.09
        r=round(r,2)
    if cnt>=5:
        test_cluster[f'apic[{i}]'] = idx
#     print('\n')

test_cluster
# Out:
# {'apic[20]': [[20, 0.09],
#   [20, 0.18],
#   [20, 0.27],
#   [20, 0.36],
#   [20, 0.45],
#   [20, 0.54],
#   [20, 0.63],
#   [20, 0.72],
#   [20, 0.81],
#   [20, 0.9]],
#  'apic[25]': [[25, 0.09], [25, 0.18], [25, 0.27], [25, 0.36], [25, 0.45]],
#  'apic[27]': [[27, 0], [27, 0.09], [27, 0.18], [27, 0.27], [27, 0.36]],
#  'apic[31]': [[31, 0],
#   [31, 0.09],
#   [31, 0.18],
#   [31, 0.27],
#   [31, 0.36],
#   [31, 0.45]],
#  'apic[33]': [[33, 0.27],
#   [33, 0.36],
#   [33, 0.45],
#   [33, 0.54],
#   [33, 0.63],
#   [33, 0.72],
#   [33, 0.81],
#   [33, 0.9]],
#  'apic[36]': [[36, 0.18], [36, 0.27], [36, 0.36], [36, 0.45], [36, 0.54]],
#  'apic[50]': [[50, 0.27],
#   [50, 0.36],
#   [50, 0.45],
#   [50, 0.54],
#   [50, 0.63],
#   [50, 0.72]],
#  'apic[60]': [[60, 0],
#   [60, 0.09],
#   [60, 0.18],
#   [60, 0.27],
#   [60, 0.36],
#   [60, 0.45],
#   [60, 0.54],
#   [60, 0.63],
#   [60, 0.72],
#   [60, 0.81],
#   [60, 0.9]],
#  'apic[63]': [[63, 0],
#   [63, 0.09],
#   [63, 0.18],
#   [63, 0.27],
#   [63, 0.36],
#   [63, 0.45],
#   [63, 0.54],
#   [63, 0.63],
#   [63, 0.72]]}

# %%
from neuron import h
from neuron import gui
import matplotlib.pyplot as plt
import numpy as np
import json

file_path = "./test_cluster.json"
with open(file_path, 'r') as json_file2:
    json_data = json.load(json_file2)

h.load_file("pyrCell.hoc")
myCell = h.pyrCell()

for i in json_data:
    print(i)
# Out:
# apic[20]
# apic[25]
# apic[27]
# apic[31]
# apic[33]
# apic[36]
# apic[50]
# apic[60]
# apic[63]

# %%
"""create like_apic[20]_rand_cluster"""
from neuron import h
import json

h.load_file("pyrCell.hoc")
myCell = h.pyrCell()


#open json file
file_path = "./distance.json"
with open(file_path, 'r') as json_file:
    json_data = json.load(json_file)
file_path2 = "./cluster.json"
with open(file_path2, 'r') as json_file2:
    json_data2 = json.load(json_file2)

key1 = ["n1","n2","n3","n4","n5"]


cut_start = 926
cut_end = 1001


test_cluster2 = []
for i in key1:
    for j in json_data2[i]:
        r=0;cnt=0;idx=[]
        for sec in range(12):
            if cut_start < json_data[f"apic[{j}]"][f'myCell.apic[{j}({r})]'] < cut_end:
                cnt+=1
                idx.append([j,r])
            r+=0.09
            r=round(r,2)
            
        if cnt>=5:
            test_cluster2.append(idx)


# result={}
# result['result'] = test_cluster2
file_path3 = "./full_apic[20]_rand_cluster.json"
with open(file_path3, 'w') as outfile:
    json.dump(test_cluster2, outfile, indent=4)
test_cluster2
# Out:
# [[[16, 0.27], [16, 0.36], [16, 0.45], [16, 0.54], [16, 0.63]],
#  [[20, 0],
#   [20, 0.09],
#   [20, 0.18],
#   [20, 0.27],
#   [20, 0.36],
#   [20, 0.45],
#   [20, 0.54],
#   [20, 0.63],
#   [20, 0.72],
#   [20, 0.81],
#   [20, 0.9],
#   [20, 0.99]],
#  [[25, 0], [25, 0.09], [25, 0.18], [25, 0.27], [25, 0.36], [25, 0.45]],
#  [[27, 0], [27, 0.09], [27, 0.18], [27, 0.27], [27, 0.36]],
#  [[28, 0],
#   [28, 0.09],
#   [28, 0.18],
#   [28, 0.27],
#   [28, 0.36],
#   [28, 0.45],
#   [28, 0.54],
#   [28, 0.63],
#   [28, 0.72],
#   [28, 0.81],
#   [28, 0.9],
#   [28, 0.99]],
#  [[30, 0],
#   [30, 0.09],
#   [30, 0.18],
#   [30, 0.27],
#   [30, 0.36],
#   [30, 0.45],
#   [30, 0.54],
#   [30, 0.63],
#   [30, 0.72],
#   [30, 0.81],
#   [30, 0.9],
#   [30, 0.99]],
#  [[31, 0], [31, 0.09], [31, 0.18], [31, 0.27], [31, 0.36], [31, 0.45]],
#  [[33, 0.27],
#   [33, 0.36],
#   [33, 0.45],
#   [33, 0.54],
#   [33, 0.63],
#   [33, 0.72],
#   [33, 0.81],
#   [33, 0.9]],
#  [[36, 0.18], [36, 0.27], [36, 0.36], [36, 0.45], [36, 0.54]],
#  [[44, 0.27],
#   [44, 0.36],
#   [44, 0.45],
#   [44, 0.54],
#   [44, 0.63],
#   [44, 0.72],
#   [44, 0.81],
#   [44, 0.9],
#   [44, 0.99]],
#  [[50, 0.27], [50, 0.36], [50, 0.45], [50, 0.54], [50, 0.63], [50, 0.72]],
#  [[55, 0.36],
#   [55, 0.45],
#   [55, 0.54],
#   [55, 0.63],
#   [55, 0.72],
#   [55, 0.81],
#   [55, 0.9],
#   [55, 0.99]],
#  [[60, 0],
#   [60, 0.09],
#   [60, 0.18],
#   [60, 0.27],
#   [60, 0.36],
#   [60, 0.45],
#   [60, 0.54],
#   [60, 0.63],
#   [60, 0.72],
#   [60, 0.81],
#   [60, 0.9]],
#  [[63, 0],
#   [63, 0.09],
#   [63, 0.18],
#   [63, 0.27],
#   [63, 0.36],
#   [63, 0.45],
#   [63, 0.54],
#   [63, 0.63],
#   [63, 0.72]]]

# %%
"""
create apic[20]'s five sections
"""
from neuron import h
import json

h.load_file("pyrCell.hoc")
myCell = h.pyrCell()

file_path = "./distance.json"
with open(file_path, 'r') as json_file:
    json_data = json.load(json_file)

file_path2 = "./full_apic[20]_rand_cluster.json"
with open(file_path2, 'r') as json_file2:
    json_data2 = json.load(json_file2)

seg_interval = 14.6
cut_start = 927
cut_end = cut_start + seg_interval

rand_cluster = {}
for i in range(5):
    idx=[]
    for data in json_data2:
        for val in data:      #val[0]= dendrite; val[1]= seg
            if cut_start < json_data[f"apic[{val[0]}]"][f'myCell.apic[{val[0]}({val[1]})]'] < cut_end:
                idx.append(val)
#                 print(json_data[f"apic[{val[0]}]"][f'myCell.apic[{val[0]}({val[1]})]'])
    rand_cluster[f'seg{i+1}']=idx
    cut_start+=seg_interval
    cut_end+=seg_interval
#     print()
    
file_path3 = "./slice_apic[20]_rand_cluster.json"
with open(file_path3, 'w') as outfile:
    json.dump(rand_cluster, outfile, indent=4)
rand_cluster
# Out:
# {'seg1': [[20, 0],
#   [20, 0.09],
#   [20, 0.18],
#   [25, 0],
#   [25, 0.09],
#   [30, 0],
#   [30, 0.09],
#   [30, 0.18],
#   [30, 0.27],
#   [30, 0.36],
#   [30, 0.45],
#   [30, 0.54],
#   [30, 0.63],
#   [30, 0.72],
#   [30, 0.81],
#   [30, 0.9],
#   [30, 0.99],
#   [31, 0],
#   [33, 0.27],
#   [36, 0.18],
#   [44, 0.27],
#   [44, 0.36],
#   [50, 0.27],
#   [55, 0.36],
#   [55, 0.45]],
#  'seg2': [[16, 0.36],
#   [20, 0.27],
#   [20, 0.36],
#   [25, 0.18],
#   [27, 0],
#   [27, 0.09],
#   [28, 0],
#   [28, 0.09],
#   [28, 0.18],
#   [31, 0.09],
#   [33, 0.36],
#   [33, 0.45],
#   [36, 0.27],
#   [44, 0.45],
#   [44, 0.54],
#   [50, 0.36],
#   [55, 0.54],
#   [55, 0.63],
#   [60, 0],
#   [60, 0.09],
#   [60, 0.18],
#   [63, 0],
#   [63, 0.09],
#   [63, 0.18]],
#  'seg3': [[16, 0.45],
#   [20, 0.45],
#   [20, 0.54],
#   [25, 0.27],
#   [27, 0.18],
#   [28, 0.27],
#   [28, 0.36],
#   [28, 0.45],
#   [31, 0.18],
#   [33, 0.54],
#   [33, 0.63],
#   [36, 0.36],
#   [44, 0.63],
#   [44, 0.72],
#   [44, 0.81],
#   [50, 0.45],
#   [50, 0.54],
#   [55, 0.72],
#   [60, 0.27],
#   [60, 0.36],
#   [60, 0.45],
#   [63, 0.27],
#   [63, 0.36]],
#  'seg4': [[16, 0.54],
#   [20, 0.63],
#   [20, 0.72],
#   [25, 0.36],
#   [27, 0.27],
#   [28, 0.54],
#   [28, 0.63],
#   [28, 0.72],
#   [28, 0.81],
#   [31, 0.27],
#   [33, 0.72],
#   [36, 0.45],
#   [44, 0.9],
#   [44, 0.99],
#   [50, 0.63],
#   [55, 0.81],
#   [55, 0.9],
#   [60, 0.54],
#   [60, 0.63],
#   [63, 0.45],
#   [63, 0.54]],
#  'seg5': [[20, 0.81],
#   [20, 0.9],
#   [25, 0.45],
#   [27, 0.36],
#   [28, 0.9],
#   [28, 0.99],
#   [31, 0.36],
#   [31, 0.45],
#   [33, 0.81],
#   [33, 0.9],
#   [36, 0.54],
#   [50, 0.72],
#   [55, 0.99],
#   [60, 0.72],
#   [60, 0.81],
#   [60, 0.9],
#   [63, 0.63],
#   [63, 0.72]]}
