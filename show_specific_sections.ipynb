# %%
"""
show like_apic[20] total_syn
"""

from neuron import h
from neuron import gui
import matplotlib.pyplot as plt

h.load_file("pyrCell.hoc")
myCell = h.pyrCell()


"""
덴드라이트 표시======
01. sectionList에 넣기
"""
sec1 = h.SectionList()

sec1.append(myCell.apic[76])
a=h.Shape()
"""
=====================
"""

a.color_list(sec1,2)   #덴드라이트 가지 표시
# Out:
# 0.0

# %%
"""
덴드라이트 색
"""

from neuron import h
from neuron import gui
import matplotlib.pyplot as plt
import numpy as np

h.load_file("pyrCell.hoc")
myCell = h.pyrCell()

stim = h.NetStim()
stim.number=5
stim.start=5000
stim.interval=200

sl=h.SectionList()
sl.append(myCell.apic[31])
sl.append(myCell.apic[63])
print(sl)

n1=0;r1=11
syns=[]
for i in range(r1+1):
    syn = h.Exp2Syn(n1, sec=myCell.apic[31])
    n1+= 1/r1
    n1=round(n1,2)
    syn.e = 0
    syn.tau1 = 0.3
    syn.tau2 = 3
    syns.append(syn)

a=h.Shape()

a.color_list(sl,2)
# Out:
# SectionList[37]
# 0.0

# %%
"""
mark
"""
"""
시냅스 표시 예시
"""


from neuron import h
from neuron import gui
import matplotlib.pyplot as plt
import numpy as np

h.load_file("pyrCell.hoc")
myCell = h.pyrCell()

stim = h.NetStim()
stim.number=5
stim.start=5000
stim.interval=200

sl=h.SectionList()
sl.append(myCell.apic[31])
sl.append(myCell.apic[63])

a=h.Shape()

n1=0;r1=11
syns=[]
for i in range(r1+1):
    syn = h.Exp2Syn(n1, sec=myCell.apic[63])
    n1+= 1/r1
    n1=round(n1,2)
    syn.e = 0
    syn.tau1 = 0.3
    syn.tau2 = 3
    a.point_mark(syn,2)
    syns.append(syn)



a.color_list(sl,2)
# Out:
# 0.0

# %%
from neuron import h
import json

h.load_file("pyrCell.hoc")
myCell = h.pyrCell()


#open json file
file_path = "./distance.json"
with open(file_path, 'r') as json_file:
    json_data = json.load(json_file)



#===========
#거리별 자르기


n1=[];n2=[];n3=[];n4=[];n5=[]
for i,dic in json_data.items():
    for j in dic:
        if j[15:17]=="0)" and dic[j] // 200 ==1:
            text = i.replace("apic","")
            text = text.replace("[","")
            text = text.replace("]","")
            n1.append(text)
        elif j[15:17]=="0)" and dic[j] // 200 ==2:
            text = i.replace("apic","")
            text = text.replace("[","")
            text = text.replace("]","")
            n2.append(text)
        elif j[15:17]=="0)" and dic[j] // 200 ==3:
            text = i.replace("apic","")
            text = text.replace("[","")
            text = text.replace("]","")
            n3.append(text)
        elif j[15:17]=="0)" and dic[j] // 200 ==4:
            text = i.replace("apic","")
            text = text.replace("[","")
            text = text.replace("]","")
            n4.append(text)
        elif j[15:17]=="0)" and dic[j] // 200 ==5:
            text = i.replace("apic","")
            text = text.replace("[","")
            text = text.replace("]","")
            n5.append(text)

#===========

        
n1 = list(map(int,n1))
n2 = list(map(int,n2))
n3 = list(map(int,n3))
n4 = list(map(int,n4))
n5 = list(map(int,n5))

print(n5)

#===========
#show shape
#===========


sec1=h.SectionList()
for i in n5:
    sec1.append(myCell.apic[i])

stim = h.NetStim()
stim.number=5
stim.start=5000
stim.interval=200


num1=0;r1=11
syns=[]
for i in range(r1+1):
    syn = h.Exp2Syn(num1, sec=myCell.apic[31])
    num1+= 1/r1
    num1=round(num1,2)
    syn.e = 0
    syn.tau1 = 0.3
    syn.tau2 = 3
    syns.append(syn)

a=h.Shape(1)
a.color_list(sec1,2)
# Out:
# [17, 18, 21, 22, 23, 24, 34, 35, 37, 38, 51, 52, 53, 54, 61, 62, 64, 65, 66, 67, 68, 69, 72, 73]
# 0.0

# %%
"""
시냅스 표시
n1~n5까지 있음

보고 싶은 n을 설정해서 하면 된다.
단, 바꿀 때는 모두 바꿔야 함. 바꿔야할 거 5개 있음.
"""

from neuron import h
from neuron import gui
import matplotlib.pyplot as plt
import numpy as np
import json

file_path2 = "./cluster.json"
with open(file_path2, 'r') as json_file2:
    json_data = json.load(json_file2)
    
n5 = json_data["n5"]

h.load_file("pyrCell.hoc")
myCell = h.pyrCell()


stim = h.NetStim()
stim.number=1
stim.start=5000
stim.interval=400

sec1=h.SectionList()
for i in n5:
    sec1.append(myCell.apic[i])

a=h.Shape()

total_syns=[]
for i in n5:
    syns=[]
    num1=0;r1=11
    for j in range(r1+1):
        syn = h.Exp2Syn(num1, sec=myCell.apic[i])
        num1+= 1/r1
        num1=round(num1,2)
        syn.e = 0
        syn.tau1 = 0.3
        syn.tau2 = 3
        a.point_mark(syn,2)   #시냅스 표시
        syns.append(syn)
    total_syns.append(syns)



total_ncs=[]
for i in range(len(n5)):
    ncs=[]
    for j in range(r1+1):
        nc = h.NetCon(stim, total_syns[i][j])
        nc.delay=1
        nc.weight[0] = 0.0003
        ncs.append(nc)
    total_ncs.append(ncs)
a.color_list(sl,2)   #덴드라이트 가지 표시
# Out:
# 0.0

# %%
"""
12/1 시냅스 나타내는 코드
"""

from neuron import h
from neuron import gui
import matplotlib.pyplot as plt
import numpy as np
import json

file_path = "./test_cluster.json"
with open(file_path, 'r') as json_file2:
    json_data = json.load(json_file2)

cluster_idx = [20,25,27,31,33,36,50,60,63]
clusterD = json_data["apic[63]"]   #여기 수정

h.load_file("pyrCell.hoc")
myCell = h.pyrCell()

"""
덴드라이트 표시======
01. sectionList에 넣기
"""
sec1=h.SectionList()
sec1.append(myCell.apic[63])   #여기 수정
a=h.Shape()
"""
=====================
"""

stim = h.NetStim()
stim.number=10
stim.start=5000
stim.interval=10

syns=[]
num1=clusterD[0][1];r1=len(clusterD)
for i in range(r1):
    syn = h.Exp2Syn(num1, sec=myCell.apic[clusterD[0][0]])
    num1+= 0.09
    num1=round(num1,2)
    syn.e = 0
    syn.tau1 = 0.3
    syn.tau2 = 3
    """
    ----------------------
    02. 시냅스 포인트 설정
    """
    a.point_mark(syn,2)
    """
    ----------------------
    """
    syns.append(syn)


"""
----------------------
03. 빨간색(2)으로 표시
"""
a.color_list(sec1,2)   #덴드라이트 가지 표시
"""
----------------------
"""
# Out:
# '\n----------------------\n'

# %%
from neuron import h
from neuron import gui
import matplotlib.pyplot as plt
import numpy as np
import json

file_path = "./test_cluster.json"
with open(file_path, 'r') as json_file2:
    json_data = json.load(json_file2)

h.load_file("pyrCell.hoc")
myCell = h.pyrCell()    



"""
덴드라이트 표시======
01. sectionList에 넣기
"""
sec1=h.SectionList()
for i in cluster_idx:
    sec1.append(myCell.apic[i])
a=h.Shape()
"""
=====================
"""


    
stim = h.NetStim()
stim.number=10
stim.start=5000
stim.interval=10

total_syns=[]
for data in json_data:
    syns=[]
    num1=json_data[data][0][1];r1=len(clusterD)
    for i in range(r1):
        syn = h.Exp2Syn(num1, sec=myCell.apic[json_data[data][0][0]])
        num1+= 0.09
        num1=round(num1,2)
        syn.e = 0
        syn.tau1 = 0.3
        syn.tau2 = 3
        """
        ----------------------
        02. 시냅스 포인트 설정
        """
        a.point_mark(syn,2)
        """
        ----------------------
        """
        syns.append(syn)
    total_syns.append(syns)
        

"""
----------------------
03. 빨간색(2)으로 표시
"""
a.color_list(sec1,2)   #덴드라이트 가지 표시
"""
----------------------
"""
# Out:
# '\n----------------------\n'

# %%
"""
show like_apic[20] total_syn
"""

from neuron import h
from neuron import gui
import matplotlib.pyplot as plt
import numpy as np
import json
import random

h.load_file("pyrCell.hoc")
myCell = h.pyrCell()

file_path = "./slice_apic[20]_rand_cluster.json"
with open(file_path, 'r') as json_file:
    json_data = json.load(json_file)

seg_list=[f'seg{x}' for x in range(1,6)]
rseg_list=[8,11,0,13,3]
cluster_Obj = json_data
randList = []

"""
덴드라이트 표시======
01. sectionList에 넣기
"""
sec1 = h.SectionList()
for seg in seg_list:
    for idx in range(len(cluster_Obj[seg])):
        s_val = cluster_Obj[seg][idx]
        sec1.append(myCell.apic[s_val[0]])
a=h.Shape()
"""
=====================
"""

stim = h.NetStim()
stim.number=1
stim.start=5000
stim.interval=0

syns=[]
for seg in seg_list:
    for idx in range(len(cluster_Obj[seg])):
        s_val = cluster_Obj[seg][idx]
        syn = h.Exp2Syn(s_val[1], sec=myCell.apic[s_val[0]])
        syn.e = 0
        syn.tau1 = 0.3
        syn.tau2 = 3
        syns.append(syn)
        """
        ----------------------
        02. 시냅스 포인트 설정
        """
        a.point_mark(syn,2)
        """
        ----------------------
        """
        syns.append(syn)

a.color_list(sec1,2)   #덴드라이트 가지 표시
# Out:
# 0.0

# %%
"""
show like_apic[20] rand_syn
"""

from neuron import h
from neuron import gui
import matplotlib.pyplot as plt
import numpy as np
import json
import random

h.load_file("pyrCell.hoc")
myCell = h.pyrCell()

file_path = "./slice_apic[20]_rand_cluster.json"
with open(file_path, 'r') as json_file:
    json_data = json.load(json_file)

seg_list=[f'seg{x}' for x in range(1,6)]
rseg_list=[24,5,3,18,16]
cluster_Obj = json_data
randList = []

"""
덴드라이트 표시======
01. sectionList에 넣기
"""
sec1 = h.SectionList()
for seg,rseg in zip(seg_list,rseg_list):
    print(seg,rseg)
    s_val = cluster_Obj[seg][rseg]
    print(s_val)
    sec1.append(myCell.apic[s_val[0]])
a=h.Shape()
"""
=====================
"""

syns=[]
for seg,rseg in zip(seg_list,rseg_list):
    s_val = cluster_Obj[seg][rseg]
    syn = h.Exp2Syn(s_val[1], sec=myCell.apic[s_val[0]])
    syn.e = 0
    syn.tau1 = 0.3
    syn.tau2 = 3
    syns.append(syn)
    """
    ----------------------
    02. 시냅스 포인트 설정
    """
    a.point_mark(syn,2)
    """
    ----------------------
    """
    syns.append(syn)

a.color_list(sec1,2)   #덴드라이트 가지 표시
# Out:
# seg1 24
# [55, 0.45]
# seg2 5
# [27, 0.09]
# seg3 3
# [25, 0.27]
# seg4 18
# [60, 0.63]
# seg5 16
# [63, 0.63]
# 0.0

# %%
"""
show like_apic[20] rand_syn
"""

from neuron import h
from neuron import gui
import matplotlib.pyplot as plt
import numpy as np
import json
import random

h.load_file("pyrCell.hoc")
myCell = h.pyrCell()

file_path = "./slice_apic[20]_rand_cluster.json"
with open(file_path, 'r') as json_file:
    json_data = json.load(json_file)

seg_list=[f'seg{x}' for x in range(1,6)]
rseg_list=[19,8,9,13,10]
cluster_Obj = json_data
randList = []

"""
덴드라이트 표시======
01. sectionList에 넣기
"""
sec1 = h.SectionList()
for seg,rseg in zip(seg_list,rseg_list):
    print(seg,rseg)
    s_val = cluster_Obj[seg][rseg]
    print(s_val)
    sec1.append(myCell.apic[s_val[0]])
a=h.Shape()
"""
=====================
"""

syns=[]
for seg,rseg in zip(seg_list,rseg_list):
    s_val = cluster_Obj[seg][rseg]
    syn = h.Exp2Syn(s_val[1], sec=myCell.apic[s_val[0]])
    syn.e = 0
    syn.tau1 = 0.3
    syn.tau2 = 3
    syns.append(syn)
    """
    ----------------------
    02. 시냅스 포인트 설정
    """
    a.point_mark(syn,2)
    """
    ----------------------
    """
    syns.append(syn)

a.color_list(sec1,2)   #덴드라이트 가지 표시

# %%
"""
show like_apic[20] rand_syn( two )
"""

from neuron import h
from neuron import gui
import matplotlib.pyplot as plt
import numpy as np
import json
import random

h.load_file("pyrCell.hoc")
myCell = h.pyrCell()

s_val_0=[44,30]
s_val_1=[0.27,0]

"""
덴드라이트 표시======
01. sectionList에 넣기
"""
sec1 = h.SectionList()
for i in range(2):
    sec1.append(myCell.apic[s_val_0[i]])
    a=h.Shape()
"""
=====================
"""

syns=[]
for i in range(2):
    syn = h.Exp2Syn(s_val_1[i], sec=myCell.apic[s_val_0[i]])
    syn.e = 0
    syn.tau1 = 0.3
    syn.tau2 = 3
    syns.append(syn)
    """
    ----------------------
    02. 시냅스 포인트 설정
    """
    a.point_mark(syn,2)
    """
    ----------------------
    """
    syns.append(syn)

a.color_list(sec1,2)   #덴드라이트 가지 표시
# Out:
# 0.0

# %%
"""
show like_apic[20] rand_syn( three )
"""

from neuron import h
from neuron import gui
import matplotlib.pyplot as plt
import numpy as np
import json
import random

h.load_file("pyrCell.hoc")
myCell = h.pyrCell()


"""
덴드라이트 표시======
01. sectionList에 넣기
"""
sec1 = h.SectionList()
sec1.append(myCell.apic[20])
sec1.append(myCell.apic[22])
sec1.append(myCell.apic[69])

a=h.Shape()

"""
=====================
"""


"""
----------------------
02. 시냅스 포인트 설정
"""
# syn1 = h.Exp2Syn(0.5, sec=myCell.soma)
# a.point_mark(syn1,2)
syn2 = h.Exp2Syn(0.36, sec=myCell.apic[20])
a.point_mark(syn2,3)
syn3 = h.Exp2Syn(0.45, sec=myCell.apic[22])
a.point_mark(syn3,2)
syn4 = h.Exp2Syn(0.18, sec=myCell.apic[69])
a.point_mark(syn4,2)
"""
----------------------
"""

a.color_list(sec1,2)   #덴드라이트 가지 표시
# Out:
# 0.0

# %%
"""
show like_apic[20] rand_syn( five )
"""

from neuron import h
from neuron import gui
import matplotlib.pyplot as plt
import numpy as np
import json
import random

h.load_file("pyrCell.hoc")
myCell = h.pyrCell()

s_val_0=[55,25,16,63,33]
s_val_1=[0.36,0.09,0.36,0.18,0.54]

"""
덴드라이트 표시======
01. sectionList에 넣기
"""
sec1 = h.SectionList()
for i in range(5):
    sec1.append(myCell.apic[s_val_0[i]])
a=h.Shape()
"""
=====================
"""

syns=[]
for i in range(5):
    syn = h.Exp2Syn(s_val_1[i], sec=myCell.apic[s_val_0[i]])
    syn.e = 0
    syn.tau1 = 0.3
    syn.tau2 = 3
    syns.append(syn)
    """
    ----------------------
    02. 시냅스 포인트 설정
    """
    a.point_mark(syn,2)
    """
    ----------------------
    """
    syns.append(syn)

a.color_list(sec1,2)   #덴드라이트 가지 표시
# Out:
# 0.0

# %%
"""
show like_apic[20] rand_syn( ten )
"""

from neuron import h
from neuron import gui
import matplotlib.pyplot as plt
import numpy as np
import json
import random

h.load_file("pyrCell.hoc")
myCell = h.pyrCell()

s_val_0=[55,30,44,25,44,28,28,55,28,63]
s_val_1=[0.36,0.81,0.45,0.18,0.63,0.36,0.54,0.9,0.9,0.72]

"""
덴드라이트 표시======
01. sectionList에 넣기
"""
sec1 = h.SectionList()
for i in range(10):
    sec1.append(myCell.apic[s_val_0[i]])
a=h.Shape()
"""
=====================
"""

syns=[]
for i in range(10):
    syn = h.Exp2Syn(s_val_1[i], sec=myCell.apic[s_val_0[i]])
    syn.e = 0
    syn.tau1 = 0.3
    syn.tau2 = 3
    syns.append(syn)
    """
    ----------------------
    02. 시냅스 포인트 설정
    """
    a.point_mark(syn,2)
    """
    ----------------------
    """
    syns.append(syn)

a.color_list(sec1,2)   #덴드라이트 가지 표시
# Out:
# 0.0

# %%
"""
show model_v102's shape (20,0.18)
"""

from neuron import h
from neuron import gui
import matplotlib.pyplot as plt
import numpy as np
import json
import random

h.load_file("pyrCell.hoc")
myCell = h.pyrCell()



"""
덴드라이트 표시======
01. sectionList에 넣기
"""
sec1 = h.SectionList()
sec1.append(myCell.apic[20])

a=h.Shape()
"""
=====================
"""

secNum = 0.09
for i in range(5):
    syn = h.Exp2Syn(secNum, sec=myCell.apic[20])
    a.point_mark(syn,2)
    secNum+=0.09
    secNum=round(secNum,2)

a.color_list(sec1,2)   #덴드라이트 가지 표시
# Out:
# 0.0

# %%
"""
show model_v102's shape (20,0.09~0.18)
"""

from neuron import h
from neuron import gui
import matplotlib.pyplot as plt
import numpy as np
import json
import random

h.load_file("pyrCell.hoc")
myCell = h.pyrCell()



"""
덴드라이트 표시======
01. sectionList에 넣기
"""
sec1 = h.SectionList()
sec1.append(myCell.apic[20])

a=h.Shape()
"""
=====================
"""

seg = 0.09
for i in range(2):
    syn = h.Exp2Syn(seg, sec=myCell.apic[20])
    syn.e = 0
    syn.tau1 = 0.3
    syn.tau2 = 3
    a.point_mark(syn,2)
    seg+=0.09

a.color_list(sec1,2)   #덴드라이트 가지 표시
# Out:
# 0.0

# %%
"""
show model_v102's shape (20,0.09 ~ 0.9)
"""

from neuron import h
from neuron import gui
import matplotlib.pyplot as plt
import numpy as np
import json
import random

h.load_file("pyrCell.hoc")
myCell = h.pyrCell()



"""
덴드라이트 표시======
01. sectionList에 넣기
"""
sec1 = h.SectionList()
sec1.append(myCell.apic[20])

a=h.Shape()
"""
=====================
"""

seg = 0.09
for i in range(10):
    syn = h.Exp2Syn(seg, sec=myCell.apic[20])
    syn.e = 0
    syn.tau1 = 0.3
    syn.tau2 = 3
    a.point_mark(syn,2)
    seg+=0.09

a.color_list(sec1,2)   #덴드라이트 가지 표시
# Out:
# 0.0

# %%
from neuron import h
from neuron import gui
import matplotlib.pyplot as plt
import numpy as np
import json
import random

h.load_file("pyrCell.hoc")
myCell = h.pyrCell()

"""
덴드라이트 표시======
01. sectionList에 넣기
"""
sec1 = h.SectionList()
sec1.append(myCell.apic[20])
a=h.Shape()
"""
=====================
"""
    
    

syns=[];seg=0.18
for i in range(5):
    syn = h.Exp2Syn(seg, sec=myCell.apic[20])
    print([20,seg])
    seg+=0.18
    syn.e = 0
    syn.tau1 = 0.3
    syn.tau2 = 3
    syns.append(syn)
    """
    ----------------------
    02. 시냅스 포인트 설정
    """
    a.point_mark(syn,2)
    """
    ----------------------
    """
# Out:
# [20, 0.18]
# [20, 0.36]
# [20, 0.54]
# [20, 0.72]
# [20, 0.8999999999999999]
